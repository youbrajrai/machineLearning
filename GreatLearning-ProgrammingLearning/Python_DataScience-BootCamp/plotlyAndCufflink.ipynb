# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
__version__
# Out:
# '4.8.1'

# %%
from plotly.offline import download_plotlyjs,iplot,init_notebook_mode

# %%
import cufflinks as cf

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.DataFrame(np.random.rand(100,4),columns =['A','B','C','D'])

# %%
df1=pd.DataFrame({'Categories':['A','B','C','D'],'Values':[2,3,4,5]})

# %%
df1
# Out:
#   Categories  Values
# 0          A       2
# 1          B       3
# 2          C       4
# 3          D       5

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="69c07edf-ff93-4392-b881-b0a63f8d9412" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("69c07edf-ff93-4392-b881-b0a63f8d9412")) {
#                     Plotly.newPlot(
#                         '69c07edf-ff93-4392-b881-b0a63f8d9412',
# ...

# %%
df.iplot(kind='scatter',x='A',y='B',mode='markers',size=30)
# Out:
# <div>
#
#
#             <div id="b6bd048c-20c4-4ac5-ae85-13234488e429" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("b6bd048c-20c4-4ac5-ae85-13234488e429")) {
#                     Plotly.newPlot(
#                         'b6bd048c-20c4-4ac5-ae85-13234488e429',
# ...

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="790361d5-e075-4c7d-bdcc-385426ec6d5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("790361d5-e075-4c7d-bdcc-385426ec6d5a")) {
#                     Plotly.newPlot(
#                         '790361d5-e075-4c7d-bdcc-385426ec6d5a',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["Categories", "Values"], "y": ["ABCD", 14]}],
# ...

# %%
df1.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="9620f939-84fe-4106-85dc-f53ec4365ccd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9620f939-84fe-4106-85dc-f53ec4365ccd")) {
#                     Plotly.newPlot(
#                         '9620f939-84fe-4106-85dc-f53ec4365ccd',
#                         [{"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(255, 153, 51, 1.0)"}, "name": "Categories", "orientation": "v", "type": "box", "y": ["A", "B", "C", "D"]}, {"boxpoints": false, "line": {"width": 1.3}, "marker": {"color": "rgba(55, 128, 191, 1.0)"}, "name": "Values", "orientation": "v", "type": "box", "y": [2, 3, 4, 5]}],
# ...

# %%
df2=pd.DataFrame({'X':[6,7,8,9],'Y':[2,3,4,5],'Z':[20,21,22,23]})

# %%
df2.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="8af6baf8-02c3-492a-9f6b-7467284c61ac" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8af6baf8-02c3-492a-9f6b-7467284c61ac")) {
#                     Plotly.newPlot(
#                         '8af6baf8-02c3-492a-9f6b-7467284c61ac',
# ...

# %%
df['A'].iplot(kind='hist',bins=30)
# Out:
# <div>
#
#
#             <div id="587ded29-65fd-4de1-8db0-13dbf9f440c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("587ded29-65fd-4de1-8db0-13dbf9f440c8")) {
#                     Plotly.newPlot(
#                         '587ded29-65fd-4de1-8db0-13dbf9f440c8',
# ...

# %%
df.iplot(kind='hist',bins=30,color='red')
# Out:
# <div>
#
#
#             <div id="5ca46c6a-c6e7-4082-b5f4-9299a65fface" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5ca46c6a-c6e7-4082-b5f4-9299a65fface")) {
#                     Plotly.newPlot(
#                         '5ca46c6a-c6e7-4082-b5f4-9299a65fface',
# ...

# %%
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="a8da9078-c453-4828-bc40-e54db7615be8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a8da9078-c453-4828-bc40-e54db7615be8")) {
#                     Plotly.newPlot(
#                         'a8da9078-c453-4828-bc40-e54db7615be8',
# ...
